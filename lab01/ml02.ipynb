# %%
import zipfile ##
import os

# Path to the downloaded zip file 
zip_file_path = r'C:\Users\Mahi2\projects\applied-ml-mk\applied-ml-mk\oral-cancer-prediction-dataset.zip'
extracted_folder = 'oral-cancer-dataset/'

# Extract the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extracted_folder)

print(f"Dataset extracted to {extracted_folder}")

import pandas as pd

# Update with the path where the dataset is located
oralcans1 = pd.read_csv(r'C:\Users\Mahi2\projects\applied-ml-mk\applied-ml-mk\lab01\oral-cancer-dataset\oral_cancer_prediction_dataset.csv')

oralcans1.head(10)
# Out:
# Dataset extracted to oral-cancer-dataset/
#    ID       Country  Age  Gender Tobacco Use Alcohol Consumption  \
# 0   1         Italy   36  Female         Yes                 Yes
# 1   2         Japan   64    Male         Yes                 Yes
# 2   3            UK   37  Female          No                 Yes
# 3   4     Sri Lanka   55    Male         Yes                 Yes
# 4   5  South Africa   68    Male          No                  No
# 5   6        Taiwan   70    Male         Yes                  No
# 6   7           USA   41  Female         Yes                 Yes
# 7   8         Italy   53    Male         Yes                 Yes
# 8   9     Sri Lanka   62  Female         Yes                  No
# 9  10       Germany   50    Male         Yes                  No
#
#   HPV Infection Betel Quid Use Chronic Sun Exposure Poor Oral Hygiene  ...  \
# 0           Yes             No                   No               Yes  ...
# ...

# %%
# Check for missing values in the "Cancer Stage" column
missing_values_in_cancer_stage = oralcans1['Cancer Stage'].isnull().sum()

# Print the number of missing values
print(f'Missing values in "Cancer Stage" column: {missing_values_in_cancer_stage}')
# Out:
# Missing values in "Cancer Stage" column: 0

# %%
oralcans1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84922 entries, 0 to 84921
# Data columns (total 25 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   ID                                        84922 non-null  int64
#  1   Country                                   84922 non-null  object
#  2   Age                                       84922 non-null  int64
#  3   Gender                                    84922 non-null  object
#  4   Tobacco Use                               84922 non-null  object
#  5   Alcohol Consumption                       84922 non-null  object
#  6   HPV Infection                             84922 non-null  object
#  7   Betel Quid Use                            84922 non-null  object
#  8   Chronic Sun Exposure                      84922 non-null  object
#  9   Poor Oral Hygiene                         84922 non-null  object
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plotting the histogram of 'Cancer Stage'
plt.figure(figsize=(8, 6))
sns.histplot(oralcans1['Cancer Stage'], bins=5, kde=False, color='skyblue')

# Add labels and title
plt.title('Histogram of Cancer Stage', fontsize=16)
plt.xlabel('Cancer Stage', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

# Show the plot
plt.show()

# %%
# Count the number of members in each Cancer Stage
cancer_stage_counts = oralcans1['Cancer Stage'].value_counts()

# Display the result
print(cancer_stage_counts)
# Out:
# Cancer Stage
# 0    42573
# 2    12865
# 1    12713
# 3    10520
# 4     6251
# Name: count, dtype: int64

# %%
# Check for missing values in the "Cancer Stage" column
missing_values_tobacco = oralcans1['Tobacco Use'].isnull().sum()

# Print the number of missing values
print(f'Missing values in "Tobacco" column: {missing_values_tobacco}')
# Out:
# Missing values in "Tobacco" column: 0

# %%
Tobacco_use_counts = oralcans1['Tobacco Use'].value_counts()

# Display the result
print(Tobacco_use_counts)
# Out:
# Tobacco Use
# Yes    67989
# No     16933
# Name: count, dtype: int64

# %%
column_names = oralcans1.columns

# Print the column names
print(column_names)
# Out:
# Index(['ID', 'Country', 'Age', 'Gender', 'Tobacco Use', 'Alcohol Consumption',
#        'HPV Infection', 'Betel Quid Use', 'Chronic Sun Exposure',
#        'Poor Oral Hygiene', 'Diet (Fruits & Vegetables Intake)',
#        'Family History of Cancer', 'Compromised Immune System', 'Oral Lesions',
#        'Unexplained Bleeding', 'Difficulty Swallowing',
#        'White or Red Patches in Mouth', 'Tumor Size (cm)', 'Cancer Stage',
#        'Treatment Type', 'Survival Rate (5-Year, %)',
#        'Cost of Treatment (USD)', 'Economic Burden (Lost Workdays per Year)',
#        'Early Diagnosis', 'Oral Cancer (Diagnosis)'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a countplot (categorical histogram) for 'Tobacco Use'
plt.figure(figsize=(8, 6))  # Set the figure size
sns.countplot(data=oralcans1, x='Tobacco Use', palette='viridis')

# Set labels and title
plt.title('Distribution of Tobacco Use')
plt.xlabel('Tobacco Use')
plt.ylabel('Count')

# Show the plot
plt.show()
# Out:
# C:\Users\Mahi2\AppData\Local\Temp\ipykernel_9308\3448920859.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=oralcans1, x='Tobacco Use', palette='viridis')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plotting the histogram of 'Tobacco Use'
plt.figure(figsize=(8, 6))
sns.histplot(oralcans1['Tobacco Use'], bins=3, kde=False, color='brown')

# Add labels and title
plt.title('Histogram of Tobacco Use', fontsize=16)
plt.xlabel('Tobacco Use', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

# Show the plot
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=oralcans1, x='Cancer Stage', hue='Tobacco Use', multiple="stack", kde=True, bins=30)

# Add labels and title
plt.title('Distribution of Cancer Stage by Tobacco Use', fontsize=16)
plt.xlabel('Cancer Stage', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

# Show the plot
plt.show()

# %%
# Create a histogram for Cancer Stage by Alcohol Consumption
plt.figure(figsize=(8, 6))
sns.histplot(data=oralcans1, x='Cancer Stage', hue='Alcohol Consumption', multiple="stack", kde=True, bins=30)

# Add labels and title
plt.title('Distribution of Cancer Stage by Alcohol Consumption', fontsize=16)
plt.xlabel('Cancer Stage', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

# Show the plot
plt.show()

# %%
oralcans1['Lifestyle Risk Factor'] = oralcans1.apply(
    lambda row: 'Low Risk' if row['Tobacco Use'] == 'No' and row['Alcohol Consumption'] == 'No' else
                ('Moderate Risk' if row['Tobacco Use'] == 'No' and row['Alcohol Consumption'] == 'Yes' else
                 ('High Risk' if row['Tobacco Use'] == 'Yes' and row['Alcohol Consumption'] == 'No' else 'Very High Risk')),
    axis=1
)
print(oralcans1[['Tobacco Use', 'Alcohol Consumption', 'Lifestyle Risk Factor']].head())

# Check the distribution of the 'Lifestyle Risk Factor' to make sure the transformation worked as expected
print(oralcans1['Lifestyle Risk Factor'].value_counts())
# Out:
#   Tobacco Use Alcohol Consumption Lifestyle Risk Factor
# 0         Yes                 Yes        Very High Risk
# 1         Yes                 Yes        Very High Risk
# 2          No                 Yes         Moderate Risk
# 3         Yes                 Yes        Very High Risk
# 4          No                  No              Low Risk
# Lifestyle Risk Factor
# Very High Risk    40825
# High Risk         27164
# Moderate Risk     10114
# Low Risk           6819
# Name: count, dtype: int64

# %%
import seaborn as sns

# Load the Howell dataset
howell_data = sns.load_dataset('howell')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 4
#       1 import seaborn as sns
#       3 # Load the Howell dataset
# ----> 4 howell_data = sns.load_dataset('howell')
#
# File c:\Users\Mahi2\projects\applied-ml-mk\applied-ml-mk\.venv\Lib\site-packages\seaborn\utils.py:573, in load_dataset(name, cache, data_home, **kws)
#     571 if not os.path.exists(cache_path):
#     572     if name not in get_dataset_names():
# --> 573         raise ValueError(f"'{name}' is not one of the example datasets.")
#     574     urlretrieve(url, cache_path)
#     575 full_path = cache_path
#
# ValueError: 'howell' is not one of the example datasets.
